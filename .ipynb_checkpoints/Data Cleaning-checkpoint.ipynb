# %% [markdown]
# ## SOCIAL MEDIA ENGAGEMENT ANALYSIS
#
# This dataset indicates social media engagement data across various metrics, including likes, shares, comments, impressions, sentiment scores, toxicity, and engagement growth.

# %% [markdown]
# ### Import Dependencies

# %%
 import matplotlib.pyplot as plt
# Out:
# /home/oyella/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
import pandas as pd

# %% [markdown]
# ### Import the dataset

# %%
engagement_df = pd.read_csv('/home/oyella/Documents/ML-Tasks/Datasets/Social Media Engagement Dataset.csv')

# %% [markdown]
# ### Display the Information in the dataset

# %%
engagement_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   post_id                  12000 non-null  object
#  1   timestamp                12000 non-null  object
#  2   day_of_week              12000 non-null  object
#  3   platform                 12000 non-null  object
#  4   user_id                  12000 non-null  object
#  5   location                 12000 non-null  object
#  6   language                 12000 non-null  object
#  7   text_content             12000 non-null  object
#  8   hashtags                 12000 non-null  object
#  9   mentions                 8059 non-null   object
#  10  keywords                 12000 non-null  object
#  11  topic_category           12000 non-null  object
#  12  sentiment_score          12000 non-null  float64
#  13  sentiment_label          12000 non-null  object
# ...

# %% [markdown]
# ### Get a description of the Dataset
# This displays the numeric description different sentiments registered, which include:likes, comments, shares, impressions, reach, engagement rate, audience and age. It shows a quick, high-level overview of the central tendency, dispersion, and shape of the dataset's distribution.

# %%
engagement_df.describe()
# Out:
#        sentiment_score  toxicity_score  likes_count  shares_count  \
# count     12000.000000    12000.000000  12000.00000  12000.000000
# mean          0.000553        0.503868   2490.72025   1007.167167
# std           0.583563        0.288198   1441.53253    575.072282
# min          -0.999800        0.000000      0.00000      0.000000
# 25%          -0.503200        0.251400   1236.00000    510.000000
# 50%          -0.006200        0.505950   2496.00000   1018.000000
# 75%           0.513525        0.756200   3723.25000   1501.000000
# max           0.999900        0.999900   5000.00000   2000.000000
#
#        comments_count   impressions  engagement_rate  user_past_sentiment_avg  \
# count     12000.00000  12000.000000     12000.000000             12000.000000
# mean        504.34575  49811.338500         0.278137                 0.001472
# std         288.68416  28930.289451         1.149206                 0.576627
# ...

# %% [markdown]
# ### Get null values

# %%
engagement_df['sentiment-label'].isnull().value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sentiment-label'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ...

# %% [markdown]
# ### Handle Missing Values
# This method does a forward fill on all the missing values in the dataset.

# %%
engagement_df.ffill()
# Out:
#         Platform                               Post ID Post Type  \
# 0       LinkedIn  d49dadb4-fc1e-4775-88ad-d60b75cf5123     Video
# 1      Instagram  16ce29c5-2dc7-478f-9814-a86754f3ce8b     Video
# 2      Instagram  6a6cc741-72f4-4111-95a0-c5ee04a175a8     Video
# 3        Twitter  0b5a3e70-c556-43cb-ad4f-a1d0003348bc     Image
# 4       Facebook  a7d3e958-e2fe-411e-a24a-b96e821fc050      Link
# ...          ...                                   ...       ...
# 99995   LinkedIn  26534a4f-0cb6-4bb3-b852-d1cadc15584e      Link
# 99996   Facebook  df9577d4-9338-4f41-99f9-8e8f1e34febd      Link
# 99997   LinkedIn  43cd806e-704b-4718-9924-2555c189f8b2      Link
# 99998  Instagram  3485970a-0f34-4304-a60a-f4e3de8e1917      Link
# 99999    Twitter  6b1406b0-adca-43e5-abde-799746a9b50a      Link
#
#       Post Timestamp  Likes  Comments  Shares  Impressions  Reach  \
# 0            19:49.3    415        77      85         2619   1842
# ...

# %% [markdown]
# ### Get the basic size and structure of the dataset

# %%
engagement_df.shape
# Out:
# (100000, 15)

# %% [markdown]
# ### Display and confirm the datatypes in the dataset.
# This lists every column in the Dataset and shows the data type assigned to it.

# %%
engagement_df.dtypes
# Out:
# Platform               object
# Post ID                object
# Post Type              object
# Post Timestamp         object
# Likes                   int64
# Comments                int64
# Shares                  int64
# Impressions             int64
# Reach                   int64
# Engagement Rate       float64
# Audience Age            int64
# Audience Gender        object
# Audience Location      object
# Audience Interests     object
# Sentiment              object
# dtype: object

# %%
engagement_df['Post Timestamp'] = pd.to_datetime(engagement_df['Post Timestamp'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 engagement_df['Post Timestamp'] = pd.to_datetime(engagement_df['Post Timestamp'])
#
# NameError: name 'engagement_df' is not defined

# %%
engagement_df.head(30)
# Out:
#      Platform                               Post ID Post Type Post Timestamp  \
# 0    LinkedIn  d49dadb4-fc1e-4775-88ad-d60b75cf5123     Video        19:49.3
# 1   Instagram  16ce29c5-2dc7-478f-9814-a86754f3ce8b     Video        40:06.4
# 2   Instagram  6a6cc741-72f4-4111-95a0-c5ee04a175a8     Video        56:53.2
# 3     Twitter  0b5a3e70-c556-43cb-ad4f-a1d0003348bc     Image        39:00.2
# 4    Facebook  a7d3e958-e2fe-411e-a24a-b96e821fc050      Link        51:21.4
# 5    Facebook  0922ea18-ea90-4302-b126-bd95f85a0926     Video        32:30.1
# 6   Instagram  0510219c-c413-4203-a9c6-e176a299ce10      Link        32:05.1
# 7    LinkedIn  c394636e-4e5c-4453-b096-597e530bd4eb      Link        32:01.6
# 8    LinkedIn  75142995-8ed2-419d-9632-72a0b631175b      Link        22:21.1
# 9     Twitter  aeaed62e-bfa7-4f81-aea7-3ce2413ac473     Video        55:37.1
# 10   Facebook  a30c948b-0fb3-4e92-95da-e2dea184f568      Link        15:59.8
# ...

# %%
# 1. Bar plot of posts per platform
plt.figure(figsize=(10, 6))
engagement_df['Platform'].value_counts().plot(kind='bar')
plt.title('Number of Posts per Platform')
plt.xlabel('Platform')
plt.ylabel('Number of Posts')
plt.tight_layout()
plt.show()

# %%
# 4. Pie chart of Audience Gender
plt.figure(figsize=(8, 8))
engagement_df['Audience Gender'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Audience Gender Distribution')
plt.ylabel('')
plt.show()

# %%
# 5. Heatmap of correlation between numeric columns
numeric_cols = ['Likes', 'Comments', 'Shares', 'Impressions', 'Reach', 'Engagement Rate']
plt.figure(figsize=(15, 8))
sns.heatmap(engagement_df[numeric_cols].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap of Numeric Variables')
plt.show()

# %%
# 6. Bar plot of top 10 Audience Locations
plt.figure(figsize=(12, 6))
engagement_df['Audience Location'].value_counts().nlargest(10).plot(kind='bar')
plt.title('Top 10 Audience Locations')
plt.xlabel('Location')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# 3. Box plot of Engagement Rate by Platform
plt.figure(figsize=(10, 6))
sns.boxplot(data=engagement_df, x='Platform', y='Engagement Rate')
plt.title('Engagement Rate Distribution by Platform')
plt.show()

# %%
# Out:
#   Cell In[3], line 1
#     git init
#         ^
# SyntaxError: invalid syntax
